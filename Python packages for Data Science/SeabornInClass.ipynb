# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

tips = sns.load_dataset('tips')
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.relplot(data = tips, x = 'total_bill', y = 'tip')

# %%
sns.relplot(data = tips, x = 'total_bill', y = 'tip', hue = 'sex')

# %%
sns.relplot(data = tips, x = 'total_bill', y = 'tip', hue = 'sex', col = 'sex')

# %%
sns.relplot(data = tips, x = 'total_bill', y = 'tip', hue = 'smoker', col = 'sex')

# %%
sns.relplot(data = tips, x = 'total_bill', y = 'tip', hue = 'size', col = 'sex')

# %%
sns.relplot(data = tips, x = 'total_bill', y = 'tip', hue = 'size', col = 'sex', size = 'size')

# %%
sns.relplot(data = tips, x = 'total_bill', y = 'tip', hue = 'size', col = 'sex', size = 'size', alpha = 0.5)

# %%
sns.relplot(data = tips, x = 'day', y = 'total_bill')

# %%
sns.relplot(data = tips, x = 'day', y = 'total_bill', kind = 'line')

# %%
sns.relplot(data = tips, x = 'day', y = 'total_bill', kind = 'line', hue = 'time')

# %%
sns.relplot(data = tips, x = 'day', y = 'total_bill', kind = 'line', hue = 'time', col = 'smoker')

# %%
sns.displot(data = tips, x = 'total_bill')

# %%
sns.displot(data = tips, x = 'total_bill', hue = 'sex')

# %%
sns.displot(data = tips, x = 'total_bill', hue = 'sex', col = 'smoker')

# %%
sns.displot(data = tips, x = 'total_bill', hue = 'sex', kind = 'kde')

# %%
sns.displot(data = tips, x = 'total_bill', hue = 'size', kind = 'kde')

# %%
sns.displot(data = tips, x = 'total_bill', hue = 'sex', kind = 'kde', multiple = 'stack')

# %%
sns.displot(data = tips, x = 'total_bill', hue = 'size', kind = 'kde', multiple = 'stack')

# %%
sns.displot(data = tips, x = 'total_bill', y = 'tip', kind = 'kde')

# %%
sns.displot(data = tips, x = 'total_bill', y = 'tip', kind = 'kde', hue ='sex')

# %%
sns.displot(data = tips, x = 'total_bill', y = 'tip', kind = 'kde', hue ='sex', rug = True)

# %%
sns.displot(data = tips, x = 'total_bill', kind = 'ecdf')

# %%
sns.displot(data = tips, x = 'total_bill', kind = 'ecdf', hue = 'sex')

# %%
sns.displot(data = tips, x = 'total_bill', kind = 'ecdf', hue = 'day')

# %%
sns.displot(data = tips, x = 'total_bill', kind = 'ecdf', hue = 'day', col = 'sex')

# %%
sns.catplot(data = tips, x = 'day', y = 'total_bill')

# %%
sns.catplot(data = tips, x = 'day', y = 'total_bill', hue = 'sex')

# %%
sns.catplot(data = tips, x = 'day', y = 'total_bill', kind = 'box')

# %%
sns.catplot(data = tips, x = 'day', y = 'total_bill', hue = 'smoker', kind = 'box')

# %%
sns.catplot(data = tips, x = 'day', y = 'total_bill', hue = 'sex', kind = 'box')

# %%
sns.catplot(data = tips, x = 'day', y = 'total_bill', hue = 'sex', kind = 'violin')

# %%
sns.catplot(data = tips, x = 'day', y = 'total_bill', hue = 'sex', kind = 'violin', split = True)

# %%
sns.catplot(data = tips, x = 'day', y = 'total_bill', hue = 'sex', kind = 'violin', split = True, inner = 'quartile')

# %%
sns.catplot(data = tips, x = 'day', y = 'total_bill', kind = 'bar')

# %%
sns.catplot(data = tips, x = 'day', y = 'total_bill', kind = 'bar', hue = 'sex')

# %%
kind = ['scatter', 'hist', 'hex', 'kde', 'reg', 'resid']

for k in kind:
  sns.jointplot(data = tips, x = 'total_bill', y = 'tip', kind = k)

# %%
sns.pairplot(data = tips)

# %%
sns.pairplot(data = tips, hue = 'sex')
